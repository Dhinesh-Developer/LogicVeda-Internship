# %%
# Real time dashboard for kafka data

# %%
import sys
# !{sys.executable} -m pip install streamlit psycopg2-binary pandas --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached streamlit-1.57.0-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# ...
#   Using cached altair-6.1.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached cachetools-7.1.1-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached protobuf-7.34.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# ...
#   Using cached pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# ...

# %%
import streamlit as st
import psycopg2
import pandas as pd

# %%
# DB connection
con = psycopg2.connect(
    host = "localhost",
    database = "kafka_db",
    user = "postgres",
    password = "arise"
)

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:arise@localhost:5432/kafka_db")

# %%
import sys
# !{sys.executable} -m pip install sqlalchemy psycopg2-binary --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# ...
#   Using cached greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# ...
# Using cached sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
# Using cached greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (611 kB)
# ...

# %%
# Title
st.title("Real-time Kafka Dashboard")

# Fetch data
query = "SELECT * FROM users ORDER BY id DESC LIMIT 100"
df = pd.read_sql(query,engine)
# Out:
# 2026-05-06 18:16:01.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-06 18:16:01.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-06 18:16:01.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import pandas as pd
from sqlalchemy import create_engine

# %%
st.set_page_config(page_title='kafka Dashboard', layout="wide")
st.title("Real-time Kafka Dashboard")
# Out:
# 2026-05-06 18:20:11.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-06 18:20:11.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-06 18:20:11.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-06 18:20:11.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
